# %%
import pandas as pd

# %%
# Read the CSV file with specified encoding
df = pd.read_csv(r"sample_data/questions (1).csv", encoding='latin1')

# Now you can proceed with processing the DataFrame
df["Answers"].iloc[0]
# Out:
# "Diabetes is a chronic metabolic disorder characterized by high blood sugar levels resulting from either insufficient insulin production by the pancreas or the body's inability to effectively use insulin. Insulin is a hormone produced by the pancreas that helps regulate blood sugar levels and allows cells to absorb glucose from the bloodstream to use as energy. Without enough insulin or if cells become resistant to insulin, glucose builds up in the bloodstream, leading to various health complications over time."

# %%
import torch
from transformers import BertForQuestionAnswering, AdamW, get_linear_schedule_with_warmup
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset

class MyDataset(Dataset):
    def __init__(self, questions, answers, tokenizer):
        self.questions = questions
        self.answers = answers
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        question = self.questions[idx]
        answer = self.answers[idx]

        encoded = self.tokenizer(question, answer, return_tensors='pt')

        return {
            'input_ids': encoded['input_ids'].squeeze(0),
            'attention_mask': encoded['attention_mask'].squeeze(0),
            'start_positions': torch.tensor([encoded['start_positions']], dtype=torch.long),
            'end_positions': torch.tensor([encoded['end_positions']], dtype=torch.long)
        }


# Split data into train and validation sets
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Define batch size
batch_size = 8

# Define data loaders
train_dataset = MyDataset(questions=train_df['Questions'].tolist(), answers=train_df['Answers'].tolist(), tokenizer=tokenizer)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = MyDataset(questions=val_df['Questions'].tolist(), answers=val_df['Answers'].tolist(), tokenizer=tokenizer)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# Initialize BERT model for question answering
model = BertForQuestionAnswering.from_pretrained('bert-base-uncased')

# Define optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)

# Move model to appropriate device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Fine-tuning loop
epochs = 3
criterion = torch.nn.CrossEntropyLoss()
total_steps = len(train_loader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

for epoch in range(epochs):
    total_loss = 0
    model.train()
    for batch in train_loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        start_positions = batch['start_positions'].squeeze(1).to(device)
        end_positions = batch['end_positions'].squeeze(1).to(device)

        # Forward pass
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        start_logits, end_logits = outputs.start_logits, outputs.end_logits

        # Compute loss
        loss = criterion(start_logits, start_positions) + criterion(end_logits, end_positions)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        total_loss += loss.item()

    # Compute average training loss
    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for val_batch in val_loader:
            input_ids = val_batch['input_ids'].to(device)
            attention_mask = val_batch['attention_mask'].to(device)
            start_positions = val_batch['start_positions'].squeeze(1).to(device)
            end_positions = val_batch['end_positions'].squeeze(1).to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            start_logits, end_logits = outputs.start_logits, outputs.end_logits

            val_loss = criterion(start_logits, start_positions) + criterion(end_logits, end_positions)

            total_val_loss += val_loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    print(f'Epoch {epoch + 1}/{epochs}: Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

# Save the fine-tuned model (optional)
torch.save(model.state_dict(), 'fine_tuned_bert.pth')

# Inference (use the fine-tuned model for question answering)
# You can use the same inference code as before, just load the fine-tuned model instead
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-29cffc34e926> in <cell line: 59>()
#      60     total_loss = 0
#      61     model.train()
# ---> 62     for batch in train_loader:
#      63         input_ids = batch['input_ids'].to(device)
#      64         attention_mask = batch['attention_mask'].to(device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-71-29cffc34e926> in __getitem__(self, idx)
#      23             'input_ids': encoded['input_ids'].squeeze(0),
#      24             'attention_mask': encoded['attention_mask'].squeeze(0),
# ---> 25             'start_positions': torch.tensor([encoded['start_positions']], dtype=torch.long),
#      26             'end_positions': torch.tensor([encoded['end_positions']], dtype=torch.long)
#      27         }
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in __getitem__(self, item)
#     252         """
#     253         if isinstance(item, str):
# --> 254             return self.data[item]
#     255         elif self._encodings is not None:
#     256             return self._encodings[item]
#
# KeyError: 'start_positions'

# %%
from transformers import BertForQuestionAnswering

# %%
model = BertForQuestionAnswering.from_pretrained('deepset/bert-base-cased-squad2')

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained('deepset/bert-base-cased-squad2')

# %%
tokenizer.encode(df["Questions"].iloc[0], truncation=True, padding=True)
# Out:
# [101, 1327, 1110, 17972, 136, 102]

# %%
from transformers import pipeline

# %%
diabeticBot = pipeline("question-answering", model=model, tokenizer=tokenizer)

# %%
with open('sample_data/context.txt', 'r') as file:
    # Read the entire content of the file
    content = file.read()
    # Print the content
    print(content)
# Out:
#   1. Why and how did I get diabetes? Diabetes occurs for a number of reasons, but the ultimate cause of the high blood sugar that characterizes the dis- order is either deficiency of the hormone insulin or a combination of insulin deficiency and resistance of the body tissues to its actions. In response to food intake, insulin is released by specialized cells in the pancreas and is necessary for adequate amounts of glucose and other nutrients from food to be absorbed into certain tissues of the body. When insulin is lacking or the body resists its actions, the level of glucose in the blood becomes excessively high and diabetes is diagnosed. The difference in the balance between the two characterizes the two major forms of diabetes—type 1 and type 2 (see Question 2). Whatever the form of diabetes, its basis is to some extent hereditary and to some extent environmental. The hereditary contribution is more or less constant throughout recent human evolution. It is the environmental component that has changed markedly over the last 100 years, leading to the dramatic rise in the frequency of diabetes in almost all societies. You developed diabetes because either you are strongly pre- disposed due to hereditary reasons or because there are factors in your lifestyle and environment (such as gain- ing weight, getting insufficient exercise, taking certain medications) that increase the likelihood of diabetes or, as is usually the case, a combination of both. This is not all bad, because the environment and lifestyle can often be changed, with dramatic improvement in the severity of the diabetes. For more on this, see Question 5.  2. What is the difference between type 1 and type 2 diabetes? Type 1 diabetes is entirely due to an almost complete deficiency of insulin. The deficiency is the result of  Deficiency A lack or shortage, especially of some- thing essential to health.  Insulin A hormone produced by the beta cells of the pancreas, which facilitates the entry of glucose and other substances into cells and which has sev- eral other functions.  Pancreas A gland deep in the abdomen, behind the stomach, that pro- duces hormones (insulin, glucagon) and digestive enzymes.  Glucose A basic sugar used to fuel body cells.  Type 1 diabetes Characterized by an almost complete deficiency of insulin due to the immune system erroneously attacking and destroying the insulin-producing cells in the pancreas.  2   2 Immune system The body’s system that protects it from foreign substances, cells, and tissues. The immune system includes the thymus, spleen, lymph nodes, lymphocytes, B-cells and T-cells, and antibodies.  Type 2 diabetes Caused by a combi- nation of body tis- sues becoming resistant to the action of insulin and the inability of the pancreas to make enough extra insulin to overcome it.  It is only in recent times, when our lifestyle and environment have caused many of us to become very insulin resist- ant, that the insulin- producing capacity is unable to compensate.  3    the immune system erroneously attacking and destroy- ing the insulin-producing cells in the pancreas. For the proper functioning of our bodies, it is neces- sary for insulin to be present at all times in the bloodstream and tissues, not only after we have eaten. Insulin is essential to maintain the structure of our tissues and prevent them from being broken down in an uncontrolled manner. Without any insulin present, our tissues literally melt away into simple compounds that leave our bodies when we urinate. Accordingly, people with type 1 diabetes have high levels of sugar and breakdown products of fat and protein in the bloodstream and urine and develop the typical symptoms described in Question 4.  Type 2 diabetes is due to a combination of our body tissues becoming resistant to the action of insulin (for the reasons described previously in Question 1) and the inability of the pancreas to make enough extra insulin to overcome it. Although this latter compo- nent of t ...

# %%
diabeticBot({
    "question": df["Questions"].iloc[0],
    "context": all_answers
})
# Out:
# {'score': 0.6826830506324768,
#  'start': 10297,
#  'end': 10320,
#  'answer': 'an autoimmune condition'}

# %%
all_answers = ' '.join(df['Answers'])

# Print or use the concatenated string
print(all_answers)
# Out:
# Diabetes is a chronic metabolic disorder characterized by high blood sugar levels resulting from either insufficient insulin production by the pancreas or the body's inability to effectively use insulin. Insulin is a hormone produced by the pancreas that helps regulate blood sugar levels and allows cells to absorb glucose from the bloodstream to use as energy. Without enough insulin or if cells become resistant to insulin, glucose builds up in the bloodstream, leading to various health complications over time. The development of diabetes is influenced by a combination of genetic predisposition and environmental factors. In type 1 diabetes, the immune system mistakenly attacks and destroys insulin-producing cells in the pancreas, leading to a lack of insulin production. Type 2 diabetes often develops due to a combination of genetic factors and lifestyle choices such as poor diet, sedentary lifestyle, obesity, and lack of physical activity, which can lead to insulin resistance and eventually impaired insulin production. Type 1 diabetes is an autoimmune condition where the immune system attacks and destroys insulin-producing beta cells in the pancreas, resulting in little to no insulin production. Type 2 diabetes involves insulin resistance, where cells fail to respond effectively to insulin, combined with inadequate insulin secretion over time. While both types result in high blood sugar levels, they have different causes and management strategies. Diabetes mellitus is a group of metabolic disorders characterized by high blood sugar levels due to defects in insulin production, insulin action, or both. On the other hand, diabetes insipidus is a rare disorder characterized by excessive thirst and urination caused by the kidneys' inability to conserve water, leading to dehydration. Unlike diabetes mellitus, diabetes insipidus does not involve problems with blood sugar regulation. Common symptoms of diabetes include increased thirst, frequent urination, unexplained weight loss, fatigue, blurred vision, slow wound healing, and recurrent infections. However, some people with diabetes may not experience noticeable symptoms, especially in the early stages of the disease. While there is currently no cure for type 1 diabetes, it can be managed with insulin therapy and other treatments to control blood sugar levels and prevent complications. Type 2 diabetes can sometimes be reversed or managed through lifestyle changes such as healthy eating, regular exercise, weight management, and medication. However, complete reversal is not always achievable, and long-term management is typically necessary. No, there are significant racial and ethnic disparities in the prevalence, management, and outcomes of diabetes. Some racial and ethnic groups, including African Americans, Hispanic/Latino Americans, Native Americans, and Asian Americans, are at higher risk of developing diabetes and experiencing complications due to various genetic, socio-economic, and cultural factors. Yes, family history is a significant risk factor for diabetes. If you have a sibling or parent with diabetes, your risk of developing the condition increases. Additionally, genetics plays a role in both type 1 and type 2 diabetes, so siblings and children of individuals with diabetes are at higher risk of developing the condition themselves. However, it's important to note that lifestyle factors also contribute to diabetes risk, so adopting healthy habits can help reduce the risk for family members. It's extremely rare for someone to have both type 1 and type 2 diabetes simultaneously. These are distinct conditions with different underlying causes. Type 1 diabetes is an autoimmune condition where the body attacks insulin-producing cells, while type 2 diabetes involves insulin resistance and inadequate insulin production. It's more likely for individuals to have complications or features of both types, rather than having both types concurrently. Yes, borderline diabetes is often refe ...
# viduals. What one person may perceive as stressful,
#  another may not. For this reason, stress is quite hard
#  to measure in real-life situations. Artificial measures
#  of accepted stress, such as electric shocks or depriva
# tion of sleep, are very hard to apply to day-to-day life.
#  However, people who report that they are more
#  stressed, regardless of the actual nature of the stress
#  itself, are more likely to suffer from diabetes. Further
# more, it has recently become apparent that measur
# able physical and psychological stress, such as that
#  caused by sleep deprivation and social stress, is more
#  likely to be associated with the presence of diabetes.
#  This may in part explain the difference in the fre
# quency of diabetes found in people of similar genetic
#  background and measurable physical characteristics
#  (body weight, amount of exercise, etc.) in different
#  regions and societies. Exactly how perceived stress,
#  whether physical, social, or psychological, leads to
#  diabetes is not yet understood Certain medications, particularly steroids like prednisone and dexamethasone, increase the risk of diabetes by raising blood sugar levels. These drugs are part of a class called glucocorticoids, which are stress hormones that naturally elevate blood sugar. Other stress hormones, like epinephrine and norepinephrine, also have this effect. Synthetic versions of these hormones found in weight loss, cold/allergy, and asthma medications, as well as certain diuretics and cholesterol drugs, can similarly raise blood sugar. Additionally, atypical antipsychotics and certain antiviral drugs used in HIV/AIDS treatment can increase the likelihood of diabetes, partly due to weight gain. Despite these risks, these medications may be crucial for a patient's health, so the prescribing physician must balance their benefits against potential diabetes risks. Monitoring blood sugar levels during treatment is essential, and if diabetes develops, appropriate treatment is necessary. Typically, when the medication is discontinued, diabetes often resolves, and treatment can be stopped. Instilling healthy habits early in life, such as promoting a balanced diet, encouraging regular physical activity, and maintaining a healthy weight, can help reduce the risk of type 2 diabetes in children. Be a role model for healthy behaviors and create a supportive environment at home that fosters healthy eating and active living. Currently, there is no known way to prevent type 1 diabetes, as it is an autoimmune condition with genetic and environmental factors contributing to its development. However, ongoing research is exploring potential strategies for preventing or delaying the onset of type 1 diabetes in at-risk individuals, such as immunomodulatory therapies or interventions targeting environmental triggers. Prevention strategies for type 2 diabetes, such as maintaining a healthy lifestyle through diet, exercise, weight management, and regular medical check-ups, can be effective regardless of age or risk factors. It's never too late to make positive changes to reduce the risk of developing diabetes and improve overall health and well-being. Even if you have prediabetes or other risk factors, proactive measures can help prevent or delay the onset of diabetes and its complications. Recognizing the signs and symptoms of diabetes is the first step in identifying the condition. Common symptoms include increased thirst, frequent urination, unexplained weight loss, fatigue, blurred vision, and slow wound healing. If you experience these symptoms, especially if they persist or worsen over time, it's essential to consult a healthcare provider for further evaluation and testing. Additionally, individuals with risk factors such as family history, obesity, sedentary lifestyle, or previous gestational diabetes should undergo regular screening tests for diabetes, even if they do not exhibit symptoms. To confirm a diagnosis of diabetes, healthcare providers typically use blood tests to measure blood sugar levels. The main tests used for diagnosing diabetes include fasting plasma glucose (FPG) test, oral glucose tolerance test (OGTT), and hemoglobin A1c (HbA1c) test. A fasting plasma glucose test measures blood sugar levels after an overnight fast, while an oral glucose tolerance test measures blood sugar levels after drinking a glucose solution. The hemoglobin A1c test provides an average of blood sugar levels over the past two to three months. Depending on the results of these tests, along with clinical symptoms and other factors, healthcare providers can determine whether an individual has diabetes and the appropriate type and management plan. The frequency of diabetes screening depends on individual risk factors and guidelines from healthcare providers. Generally, adults should undergo screening for type 2 diabetes every 3 years starting at age 45. However, individuals with risk factors such as family history, obesity, high blood pressure, o ...
# Hemoglobin A1c (HbA1c): This blood test provides an average of blood sugar levels over the past two to three months and is used to assess long-term blood sugar control.
# Fasting plasma glucose (FPG) test: This test measures blood sugar levels after an overnight fast and helps assess fasting blood sugar control.
# Oral glucose tolerance test (OGTT): This test measures blood sugar levels before and after consuming a glucose solution to evaluate how your body processes sugar and assess glucose tolerance.
# Blood pressure monitoring: High blood pressure is a common complication of diabetes and increases the risk of cardiovascular disease. Regular blood pressure checks are essential for managing diabetes and preventing complications.
# Lipid profile: This blood test measures cholesterol levels, including LDL (bad) cholesterol, HDL (good) cholesterol, and triglycerides, to assess cardiovascular risk and guide lipid-lowering treatment if needed.
# Kidney function tests: Tests such as serum creatinine, estimated glomerular filtration rate (eGFR), and urine albumin-to-creatinine ratio (ACR) help assess kidney function and detect early signs of diabetic kidney disease (nephropathy).
# Eye exams: Regular dilated eye exams are essential for detecting diabetic retinopathy, a common complication of diabetes that can lead to vision loss if left untreated.
# Foot exams: Regular foot exams help detect diabetic neuropathy (nerve damage) and foot complications such as ulcers or infections, which can lead to serious complications if not promptly treated. Regular monitoring tests are essential for effectively managing diabetes and preventing complications. Your doctor may recommend several tests on a regular basis to assess your diabetes control and overall health. These tests may include hemoglobin A1c (HbA1c) to measure average blood sugar levels over the past two to three months, fasting plasma glucose (FPG) test to assess fasting blood sugar levels, oral glucose tolerance test (OGTT) to evaluate glucose tolerance and insulin resistance, lipid profile to measure cholesterol levels and assess cardiovascular risk, kidney function tests (e.g., serum creatinine, estimated glomerular filtration rate, urine albumin-to-creatinine ratio) to detect early signs of diabetic kidney disease, blood pressure monitoring to assess cardiovascular health, eye exams to screen for diabetic retinopathy, and foot exams to detect neuropathy and foot complications. These tests help your doctor tailor your diabetes treatment plan, identify any complications early, and make necessary adjustments to optimize your health outcomes. The best glucose monitor for you depends on your individual preferences, lifestyle, and monitoring needs. Traditional fingerstick glucose meters are widely used and offer accurate blood sugar readings, but they require frequent finger pricks for testing. Continuous glucose monitors (CGMs) provide real-time glucose readings through a sensor placed under the skin and may be beneficial for individuals who require frequent blood sugar monitoring or who want to track glucose trends over time. CGMs can provide valuable insights into blood sugar patterns, help identify trends and patterns, and facilitate more informed diabetes management decisions. Some CGM systems also offer customizable alerts for hypo- and hyperglycemia, shareable data reports, and integration with insulin pumps or smartphone apps for enhanced convenience and monitoring capabilities. Ultimately, the best glucose monitor is one that meets your specific needs, preferences, and lifestyle while providing accurate and reliable blood sugar readings. Continuous glucose monitors (CGMs) offer several advantages over traditional fingerstick glucose meters, including real-time glucose readings, trend data, and customizable alerts for hypo- and hyperglycemia. If you require frequent blood sugar monitoring or want to track glucose patterns over time, a CGM may be beneficial for you. CGMs can help you make more informed diabetes management decisions, optimize blood sugar control, and detect trends or patterns that may require adjustments to your treatment plan. Additionally, some CGM systems offer integration with insulin pumps or smartphone apps for enhanced convenience and monitoring capabilities. However, it's essential to consider factors such as cost, insurance coverage, sensor insertion and wearability, calibration requirements, and personal preferences when deciding whether to invest in a CGM system. Consult with your healthcare provider to discuss whether a CGM is suitable for your individual needs and circumstances. Stress can significantly impact blood sugar levels through various physiological and behavioral mechanisms. During times of stress, the body releases stress hormones such as cortisol and adrenaline, which trigger a cascade of metabolic responses aimed at preparing the body for a "fight or flight" response. These stress hormones can lead to increased glucose production by the liver, reduced insulin sensitivity in peripheral tissues, and an elevation in blood sugar levels. Additionally, stress can influence eating habits, physical activity levels, medication adherence, and sleep patterns, all of which can affect blood sugar control. Chronic or prolonged stress can exacerbate insulin resistance, impair glucose metabol ...
#
# When administering medication or attending to health concerns, seek out quieter areas away from crowds, such as empty corners or less-trafficked sections. Utilize clothing or accessories to discreetly cover injection sites or facilitate discreet access as needed. Maintain composure and confidence to avoid attracting undue attention, recognizing that most individuals are absorbed in their own activities. With these measures, managing your health discreetly in public becomes a seamless aspect of your routine. Individuals who require the expertise of a diabetes specialist physician typically include those with complex or poorly controlled diabetes, as well as individuals experiencing complications or comorbidities associated with the condition. Additionally, newly diagnosed diabetes patients seeking comprehensive education, guidance, and personalized treatment plans may benefit from the specialized knowledge and support offered by a diabetes specialist. Moreover, individuals with type 1 diabetes, gestational diabetes, or specific diabetes-related syndromes may require the specialized care provided by an endocrinologist or diabetologist. Furthermore, patients who need advanced therapies such as insulin pumps or continuous glucose monitoring systems may seek the expertise of a diabetes specialist to optimize their management. Overall, anyone seeking comprehensive and tailored care for diabetes management or experiencing challenges in controlling their blood sugar levels may benefit from consulting a diabetes specialist physician. Managing insulin shots during time changes requires careful planning and adjustment to maintain stable blood sugar levels. Firstly, consult with your healthcare provider to develop a plan tailored to your specific insulin regimen and travel schedule. Consider gradually adjusting your injection times by small increments over a few days leading up to the time change to minimize disruption to your routine. Use technology such as insulin pumps or continuous glucose monitoring systems, which can help automate adjustments based on changes in time zones. Additionally, monitor your blood sugar levels closely during and after the time change, making necessary corrections to your insulin dosage or timing as advised by your healthcare provider. Stay vigilant for signs of hypo- or hyperglycemia, especially during the transition period, and be prepared to adjust your insulin regimen accordingly. With careful planning and monitoring, you can effectively manage your insulin shots through time changes while maintaining optimal blood sugar control. To ensure a smooth transition and effective management of insulin shots at school, several steps can be taken in collaboration with the school administration and healthcare team. Firstly, communicate openly with the school nurse or designated staff about your insulin regimen, dosage requirements, and any special considerations. Provide clear instructions and written documentation outlining the administration protocol, emergency procedures, and contact information for your healthcare provider. Work with the school to establish a designated and private area where you can administer your insulin shots comfortably and discreetly. Additionally, educate key school personnel, such as teachers and administrators, about diabetes management and signs of hypo- or hyperglycemia to promote a supportive and informed environment. Collaborate with the school to develop a comprehensive care plan that outlines responsibilities, accommodations, and protocols for managing your diabetes during school hours. Regular communication between you, the school, and your healthcare team is essential for addressing any concerns or adjustments needed to ensure a safe and successful experience managing insulin shots at school. Preparing for managing diabetes at school involves several important steps to ensure a smooth and safe experience. Firstly, educate yourself and your child (if applicable) about diabetes  ...

# %%
len(all_answers)
# Out:
# 81118

# %%
content = content[0:5000]

# %%
import nltk
nltk.download('punkt')  # Download the necessary tokenizer data

from nltk.tokenize import sent_tokenize

# Tokenize the string into sentences
data = sent_tokenize(all_answers)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import torch
from transformers import BertTokenizer, BertModel
# Load the BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
# Tokenize and pad preprocessed sentences
tokenize_sentences = [tokenizer.encode(sentence, add_special_tokens=True) for sentence in data]
max_len = max(len(sentence) for sentence in tokenize_sentences)
padded_sentences = [sentence + [tokenizer.pad_token_id] * (max_len - len(sentence)) for sentence in tokenize_sentences]

# Convert tokenized sentences to tensor
input_ids = torch.tensor(padded_sentences)

# Define batch size
batch_size = 1000

# Compute embeddings in batches
num_samples = len(input_ids)
embeddings = []
for start in range(0, num_samples, batch_size):
    end = min(start + batch_size, num_samples)
    batch_input_ids = input_ids[start:end]

    # Create attention mask for the batch
    batch_attention_mask = torch.where(batch_input_ids != tokenizer.pad_token_id, 1, 0)

    # Model inference to get embeddings for the batch
    with torch.no_grad():
        batch_outputs = model(batch_input_ids, attention_mask=batch_attention_mask)
        batch_embeddings = batch_outputs.last_hidden_state.mean(dim=1)

    embeddings.append(batch_embeddings)

# Concatenate embeddings from all batches
embeddings = torch.cat(embeddings, dim=0)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Example sentence for similarity comparison
example_sentence = "what are the consequences of diabetes?"



# Tokenize and encode the example sentence
example_encoding = tokenizer.batch_encode_plus(
    [example_sentence],
    padding=True,
    truncation=True,
    return_tensors='pt',
    add_special_tokens=True
)
example_input_ids = example_encoding['input_ids']
example_attention_mask = example_encoding['attention_mask']

# Generate embeddings for the example sentence
with torch.no_grad():
    example_outputs = model(example_input_ids, attention_mask=example_attention_mask)
    example_sentence_embedding = example_outputs.last_hidden_state.mean(dim=1)

# Compute cosine similarity between the original sentence embedding and the example sentence embedding
similarity_score = cosine_similarity(embeddings, example_sentence_embedding)

# Print the similarity score
print("Cosine Similarity Score:", similarity_score[0][0])
# Out:
# Cosine Similarity Score: 0.51076204

# %%
import numpy as np

# Assuming you have already computed `top_indices` which contains the indices of the top 5 most similar sentences
top_indices = np.argsort(similarity_score.squeeze())[::-1][:50]
# Collect the top 5 similar sentences
top_sentences = [data[idx] for idx in top_indices]

# Combine the top sentences into a single context
context = " ".join(top_sentences)

# %%
diabeticBot({
    "question": example_sentence,
    "context": context
})
# Out:
# {'score': 0.7298672199249268,
#  'start': 14,
#  'end': 68,
#  'answer': 'increases the risk of developing other health problems'}

# %%
context
# Out:
# "Instilling healthy habits early in life, such as promoting a balanced diet, encouraging regular physical activity, and maintaining a healthy weight, can help reduce the risk of type 2 diabetes in children. A healthy lifestyle that includes regular physical activity and balanced nutrition can improve insulin sensitivity, promote weight loss, lower blood sugar levels, reduce the need for medications, and lower the risk of complications associated with diabetes. It's important to continue monitoring blood sugar levels regularly and maintain a healthy lifestyle to sustain the benefits of weight loss and diabetes management."
